# %%
import genstudio.plot as Plot

six_points = [[1, 1], [2, 4], [1.5, 7], [3, 10], [2, 13], [4, 15]]

Plot.line(six_points)
# Out:
# Widget(data=<genstudio.plot_spec.PlotSpec object at 0x1145035c0>)
